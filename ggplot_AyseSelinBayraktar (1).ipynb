# %%
'Name: Ayse Selin Bayraktar'
'Library: ggplot'
'Description:
'This library dedicated to data visualization. 
'It can greatly improve the quality and aesthetics of your graphics, 
'and will make you much more efficient in creating them.

# %%
# !pip install ggplot

# %%
pip install plotnine
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from plotnine import ggplot, aes, geom_point

# %%
import pandas as pd
file_path = "C:/Users/NOT_A/Downloads/Housing.csv"
df = pd.read_csv(file_path)

# Create a scatter plot
(
    ggplot(df, aes(x='area', y='price')) +
    geom_point()
)

# %%
import numpy as np
from pandas.api.types import CategoricalDtype
from plotnine import *
from plotnine.data import mpg
# %matplotlib inline

(ggplot(df)         # defining what data to use
 + aes(x='bedrooms')    # defining what variable to use
 + geom_bar(size=20) # defining the type of plot to use
)
